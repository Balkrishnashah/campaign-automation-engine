# %%
import pandas as pd
input_df = pd.read_csv("/Users/balkrishna/Documents/Projects/market_place_360/campaign/export/sms_2326.csv")

# %%
curr_df = input_df.copy()
curr_df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'first_name', 'last_name', 'email', 'gender',
#        'current_product', 'target_product', 'analyst_email', 'execution_type',
#        'sms_template_id', 'campaign_id', 'segment_id', 'campaign_name',
#        'campaign_execution_count', 'product_pitched'],
#       dtype='object')

# %%
curr_df.drop()
